# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray Resources/establishments.json`

# %%
! mongoimport --type json -d uk_food -c establishments --drop --jsonArray Resources/establishments.json
# Out:
# 2024-01-01T16:05:39.597-0600	connected to: mongodb://localhost/
# 2024-01-01T16:05:39.598-0600	dropping: uk_food.establishments
# 2024-01-01T16:05:41.420-0600	39779 document(s) imported successfully. 0 document(s) failed to import.

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'artifacts', 'class_db', 'config', 'epa', 'fruits_db', 'garden_db', 'local', 'met', 'petsitly_marketing', 'uk_food']

# %%
# assign the uk_food database to a variable name
food_db = mongo['uk_food']

# %%
# review the collections in our new database
print(food_db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(food_db.establishments.find_one())
# Out:
# {'AddressLine1': 'Reach Court Farm',
#  'AddressLine2': 'Reach Road',
#  'AddressLine3': 'St Margarets At Cliffe',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Barn',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.77622109052,
#  'FHRSID': 429982,
#  'LocalAuthorityBusinessID': 'PI/000043978',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6AQ',
#  'RatingDate': '2017-09-21T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65933733e41f23dd29222437'),
#  'geocode': {'latitude': '51.147379', 'longitude': '1.371115'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/429982',
# ...

# %%
# assign the collection to a variable
estb = food_db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_rest = {'BusinessName': 'Penang Flavours', 
                   'BusinessType': 'Restaurant/Cafe/Canteen', 
                   'BusinessTypeID': '', 
                   'AddressLine1': 'Penang Flavours', 
                   'AddressLine2': '146A Plumstead Rd', 
                   'AddressLine3': 'London', 
                   'AddressLine4': '', 
                   'PostCode': 'SE18 7DY', 
                   'Phone': '', 
                   'LocalAuthorityCode': '511', 
                   'LocalAuthorityName': 'Greenwich', 
                   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 
                   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 
                   'scores': {'Hygiene': '', 
                              'Structural': '', 
                              'ConfidenceInManagement': ''}, 
                   'SchemeType': 'FHRS', 
                   'geocode': {'longitude': '0.08384000', 
                                'latitude': '51.49014200'}, 
                   'RightToReply': '', 
                   'Distance': 4623.9723280747176, 
                   'NewRatingPending': True
                   }

# %%
# Insert the new restaurant into the collection
estb.insert_one(new_rest)

# %%
# Check that the new restaurant was inserted
pprint(estb.find_one(new_rest))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6593374b8f93670bffc904fc'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
q_1 = {'BusinessType': 'Restaurant/Cafe/Canteen'}
flds_1 = {"BusinessTypeID": 1, "BusinessType": 1}
#put result of query and fields in list
rslt_1 = list(estb.find(q_1, flds_1))
#pprint result
pprint(rslt_1)
# Out:
# [{'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65933733e41f23dd29222437')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65933733e41f23dd29222438')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65933733e41f23dd2922243a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65933733e41f23dd2922243b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65933733e41f23dd29222440')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65933733e41f23dd29222441')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65933733e41f23dd29222442')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('65933733e41f23dd29222444')},
# ...

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
estb.update_many(
    {'BusinessType' : 'Restaurant/Cafe/Canteen'},
    {'$set' : {'BusinessTypeID' : 1}})

# %%
# Confirm that the new restaurant was updated
q_2 = {'BusinessName' : 'Penang Flavours'}
#put the result in a list to be able to display it
rslt_2 = list(estb.find(q_2))
#pprint result
pprint(rslt_2)
# Out:
# [{'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'Distance': 4623.972328074718,
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': True,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6593374b8f93670bffc904fc'),
#   'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#   'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}]

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
q_3 = {'LocalAuthorityName' : 'Dover'}
rslt_3 = estb.count_documents(q_3)
print('Number in Dover: ', rslt_3)
# Out:
# Number in Dover:  994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
estb.delete_many({'LocalAuthorityName' : 'Dover'})

# %%
# Check if any remaining documents include Dover
rslt_3 = estb.count_documents(q_3)
print('Number left in Dover: ', rslt_3)
# Out:
# Number left in Dover:  0

# %%
# Check that other documents remain with 'find_one'
pprint(estb.find_one())
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65933733e41f23dd2922271d'),
#  'geocode': {'latitude': '51.086058', 'longitude': '1.196408'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
# ...

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
estb.update_many({}, [ {'$set': {"geocode.longitude" : {'$toDecimal' : '$geocode.longitude'},
                                 "geocode.latitude" : {'$toDecimal' : '$geocode.latitude'}
                                }
                       }
                     ]
                )

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
estb.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
estb.update_many({}, [ {'$set': {"RatingValue" : {'$toInt' : '$RatingValue'},
                                }
                       }
                     ]
                )

# %%
# Check that the coordinates and rating value are now numbers
[doc for doc in estb.find({}, ['geocode.longitude', 'geocode.latitude', 'RatingValue'])]
# Out:
# [{'_id': ObjectId('65933733e41f23dd2922271d'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.196408'),
#    'latitude': Decimal128('51.086058')}},
#  {'_id': ObjectId('65933733e41f23dd2922271e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.195625'),
#    'latitude': Decimal128('51.083812')}},
#  {'_id': ObjectId('65933733e41f23dd2922271f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.194762'),
#    'latitude': Decimal128('51.085797')}},
#  {'_id': ObjectId('65933733e41f23dd29222722'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.188537'),
#    'latitude': Decimal128('51.08084')}},
#  {'_id': ObjectId('65933733e41f23dd29222724'),
#   'RatingValue': 5,
#   'geocode': {'longitude': Decimal128('1.188537'),
#    'latitude': Decimal128('51.08084')}},
#  {'_id': ObjectId('65933733e41f23dd29222725'),
#   'RatingValue': 4,
#   'geocode': {'longitude': Decimal128('1.188537'),
# ...
